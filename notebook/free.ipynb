# %%
import pandas as pd
# %run ../country-comparison/compare.py

pd.options.display.max_columns=500
pd.options.display.max_rows=500
pd.options.display.max_colwidth=500

# %%
df = pd.read_csv('../data/result/numbeo_gdp_homi.csv')

# %%
df.head(2)
# Out:
#    Quality of Life Index  Purchasing Power Index  Safety Index  \
# 0                 188.36                  102.77         78.38
# 1                 186.25                   86.43         73.78
#
#    Health Care Index  Cost of Living Index  Property Price to Income Ratio  \
# 0              74.08                125.02                            8.18
# 1              79.79                 88.53                            7.00
#
#    Traffic Commute Time Index  Pollution Index  Climate Index      country  \
# 0                       28.67            19.86          80.05  Switzerland
# 1                       28.69            21.29          81.80      Denmark
#
#      gdp_ppp  homicide_rate
# 0  78111.508            0.6
# 1  63404.856            1.0

# %%
df['homi_score'] = default_minmax_scaling(df['homicide_rate'].values.reshape((-1, 1)))

# %%
df[['country', 'homi_score']].sort_values(by='homi_score')
# Out:
#                      country  homi_score
# 31                 Singapore    0.000000
# 15                     Japan    0.002762
# 13                      Oman    0.002762
# 9                 Luxembourg    0.002762
# 73                 Indonesia    0.005525
# 26                     Qatar    0.005525
# 23      United Arab Emirates    0.008287
# 63                     China    0.008287
# 14                  Slovenia    0.008287
# 10                    Norway    0.008287
# 20            Czech Republic    0.011050
# 17                     Spain    0.011050
# 0                Switzerland    0.011050
# 36                     Italy    0.011050
# 44                     Korea    0.011050
# 2                Netherlands    0.011050
# 24                   Croatia    0.011050
# 8                New Zealand    0.013812
# 42                    Poland    0.013812
# 71             Hong Kong SAR    0.013812
# 19                  Portugal    0.016575
# 35  Taiwan Province of China    0.016575
# ...
