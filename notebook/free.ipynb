# %%
import pandas as pd
# %run ../country_comparison/compare.py

pd.options.display.max_columns=500
pd.options.display.max_rows=500
pd.options.display.max_colwidth=500

# %%
df = pd.read_csv('../data/result/numbeo_gdp_homi.csv')

# %%
df.head(2)
# Out:
#    Quality of Life Index  Purchasing Power Index  Safety Index  \
# 0                 188.36                  102.77         78.38
# 1                 186.25                   86.43         73.78
#
#    Health Care Index  Cost of Living Index  Property Price to Income Ratio  \
# 0              74.08                125.02                            8.18
# 1              79.79                 88.53                            7.00
#
#    Traffic Commute Time Index  Pollution Index  Climate Index      country  \
# 0                       28.67            19.86          80.05  Switzerland
# 1                       28.69            21.29          81.80      Denmark
#
#      gdp_ppp  homicide_rate
# 0  78111.508            0.6
# 1  63404.856            1.0

# %%
df['homi_score'] = default_minmax_scaling(df['homicide_rate'].values.reshape((-1, 1)))

# %%
res_df = pd.read_csv('../data/result/res_df.csv')

# %%
res_df.sort_values(by='final_score', ascending=False).reset_index(drop=True)
# Out:
#                      country  final_score
# 0                 Luxembourg   187.893153
# 1                    Ireland   173.635909
# 2                Switzerland   171.278369
# 3                  Singapore   167.384442
# 4               South Africa   165.861650
# 5                      Qatar   164.301166
# 6                    Denmark   156.604857
# 7              United States   156.472054
# 8                     Norway   150.583543
# 9                Netherlands   149.491721
# 10                   Iceland   145.892476
# 11                   Austria   145.343515
# 12      United Arab Emirates   143.759713
# 13                    Mexico   143.408050
# 14               Puerto Rico   143.371979
# 15                   Germany   143.017147
# 16                   Finland   142.835100
# 17                 Australia   142.822633
# 18                    Sweden   139.090901
# 19               New Zealand   129.389931
# 20                   Estonia   127.581680
# ...

# %%
res_df.sort_values(by='final_score', ascending=False).reset_index(drop=True)
# Out:
#                      country  final_score
# 0                 Luxembourg   100.000000
# 1                    Ireland    91.814240
# 2                Switzerland    90.460664
# 3                  Singapore    88.224976
# 4               South Africa    87.350669
# 5                      Qatar    86.454721
# 6                    Denmark    82.035905
# 7              United States    81.959656
# 8                     Norway    78.578783
# 9                Netherlands    77.951916
# 10                   Iceland    75.885419
# 11                   Austria    75.570234
# 12      United Arab Emirates    74.660898
# 13                    Mexico    74.458992
# 14               Puerto Rico    74.438282
# 15                   Germany    74.234556
# 16                   Finland    74.130034
# 17                 Australia    74.122876
# 18                    Sweden    71.980312
# 19               New Zealand    66.410525
# 20                   Estonia    65.372322
# ...
