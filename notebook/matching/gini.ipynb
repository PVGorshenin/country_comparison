# %%
import pandas as pd

pd.options.display.max_columns=500
pd.options.display.max_rows=500
pd.options.display.max_colwidth=500

# %%
mega_df = pd.read_csv('../../data/result/mega_table.csv')
gini_df = pd.read_csv('../../data/intermediate/gini_short.csv')

# %%
gini_df.head(2)
# Out:
#                        country  gini
# 0                        Aruba   NaN
# 1  Africa Eastern and Southern   NaN

# %%
mega_minus_gini = set(mega_df['country']) - set(gini_df['country']) 
mega_minus_gini
# Out:
# {'Egypt', 'Hong Kong SAR', 'Iran', 'Korea', 'Taiwan Province of China'}

# %%
# %run ../clean_country.py

# %%
match_country_spelling(gini_df,
                       mega_minus_gini,
                       is_first_word=True,
                      country_col='country')
# Out:
# {'Egypt': 'Egypt, Arab Rep.',
#  'Iran': 'Iraq',
#  'Korea': 'Korea, Rep.',
#  'Hong Kong SAR': 'Hong Kong SAR, China',
#  'Taiwan Province of China': 'Thailand'}

# %%
gini_df
# Out:
#                                                   country  gini
# 0                                                   Aruba   NaN
# 1                             Africa Eastern and Southern   NaN
# 2                                             Afghanistan   NaN
# 3                              Africa Western and Central   NaN
# 4                                                  Angola  51.3
# 5                                                 Albania  33.2
# 6                                                 Andorra   NaN
# 7                                              Arab World   NaN
# 8                                    United Arab Emirates  26.0
# 9                                               Argentina  42.9
# 10                                                Armenia  29.9
# 11                                         American Samoa   NaN
# 12                                    Antigua and Barbuda   NaN
# 13                                              Australia  34.4
# ...

# %%
gini_df.loc[gini_df['country']=="Korea, Rep.", 'country'] = 'Korea'
gini_df.loc[gini_df['country']=='Hong Kong SAR, China', 'country'] = 'Hong Kong SAR'
gini_df.loc[gini_df['country']=='Egypt, Arab Rep.', 'country'] = 'Egypt'
gini_df.loc[gini_df['country']=='Iran, Islamic Rep.', 'country'] = 'Iran'

# %%
mega_minus_gini = set(mega_df['country']) - set(gini_df['country']) 
mega_minus_gini
# Out:
# {'Taiwan Province of China'}

# %%
res_df = mega_df.merge(gini_df[['country', 'gini']], how='left', on='country')
res_df.shape
# Out:
# (82, 18)

# %%
#source statista.com
res_df.loc[res_df['country']=='Taiwan Province of China', 'gini'] = 34

# %%
res_df.loc[res_df['gini'].isnull(), ['country', 'gini']]
# Out:
#           country  gini
# 8     New Zealand   NaN
# 13           Oman   NaN
# 26          Qatar   NaN
# 31      Singapore   NaN
# 33   Saudi Arabia   NaN
# 53         Kuwait   NaN
# 54         Jordan   NaN
# 66     Azerbaijan   NaN
# 70  Hong Kong SAR   NaN

# %%
#source worldpopulationreview.com

res_df.loc[res_df['country']=='New Zealand', 'gini'] = 36.2
res_df.loc[res_df['country']=='Qatar', 'gini'] = 41.1
res_df.loc[res_df['country']=='Singapore', 'gini'] = 45.9
res_df.loc[res_df['country']=='Jordan', 'gini'] = 33.7
res_df.loc[res_df['country']=='Azerbaijan', 'gini'] = 26.6
res_df.loc[res_df['country']=='Hong Kong SAR', 'gini'] = 53.9
res_df.loc[res_df['country']=='Saudi Arabia', 'gini'] = 45.9

# %%
res_df.loc[res_df['country']=='Kuwait', 'gini'] = 50 #no info for kuwait, high value is a penalty for a closeness
res_df.loc[res_df['country']=='Oman', 'gini'] = 41.1 #tradingeconomics

# %%
res_df.loc[res_df['gini'].isnull(), ['country', 'gini']]
# Out:
# Empty DataFrame
# Columns: [country, gini]
# Index: []

# %%
res_df.to_csv('../../data/result/mega_table.csv', index=None)

# %%
res_df['gini'].min()
# Out:
# 24.6
