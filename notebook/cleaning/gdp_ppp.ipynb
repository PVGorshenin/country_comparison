# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

pd.options.display.max_columns=500
pd.options.display.max_rows=500
pd.options.display.max_colwidth=500

# %% [markdown]
# #### Make it short

# %%
gdp_df = pd.read_csv('../data/intermediate/gdp_per_cap_ppp/gdp_per_capita_ppp.csv')

# %%
gdp_df.columns = [col.strip() for col in gdp_df.columns]
gdp_df.columns
# Out:
# Index(['GDP per capita, current prices (Purchasing power parity; international dollars per capita)',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024',
#        '2025', '2026'],
#       dtype='object')

# %%
gdp_df.rename({'GDP per capita, current prices (Purchasing power parity; international dollars per capita)': 'country'}, 
              axis=1, 
              inplace=True)

# %%
has_data = gdp_df['2021'] != 'no data'
gdp_df = gdp_df[has_data]

gdp_df['2021'] = gdp_df['2021'].astype(float)

# %%
gdp_df[['country', '2021']].dropna().to_csv('../data/intermediate/gdp_per_cap_ppp/gdp_per_capita_short.csv', 
                                            index=None)

# %% [markdown]
# #### Try scaling

# %%
# %run ../country-comparison/compare.py

# %%
gdp_df = pd.read_csv('../data/intermediate/gdp_per_cap_ppp/gdp_per_capita_short.csv')

# %%
gdp_arr = gdp_df['2021'].values.reshape(-1, 1).astype(float)
gdp_df['score'] = default_minmax_scaling(gdp_arr, 0.02, .98).round(3)

# %%
gdp_df
# Out:
#                                       country        2021  score
# 1                                     Albania       15487   0.12
# 2                                     Algeria   11828.518   0.09
# 3                                     Andorra   55763.618   0.44
# 4                                      Angola    6819.601   0.05
# 5                         Antigua and Barbuda   18801.393   0.14
# 6                                   Argentina   22891.696   0.18
# 7                                     Armenia   14700.692   0.11
# 8                                       Aruba   34902.073   0.27
# 9                                   Australia   55492.205   0.43
# 10                                    Austria    59405.59   0.47
# 11                                 Azerbaijan   15299.073   0.12
# 12                               Bahamas, The   34731.722   0.27
# 13                                    Bahrain   53127.617   0.42
# ...

# %% [markdown]
# ### Some postproc

# %%
gdp_df = pd.read_csv('../data/intermediate/gdp_per_cap_ppp/gdp_per_capita_short.csv')

# %%
gdp_df['country'] = gdp_df['country'].map(lambda z: z.split(',')[0])

# %%
is_country = 193
gdp_df = gdp_df.iloc[:is_country]

# %%
gdp_df[['country', '2021']].dropna().to_csv('../data/intermediate/gdp_per_cap_ppp/gdp_per_capita_short.csv', 
                                            index=None)
